# %% [markdown]
# DS is the process of using data,statistics,programming and machine learning to discover useful insights sove problems and make better decision

# %% [markdown]
# # Programing
#
# * Python or R
#
# # Data processing
#
# * Numpy and Panda
#
# # Math Statistics
#
# * Probality,Statistic,linear algebra and calculus
# # Data visualization
# *
# # Machine Learning
#
# * supervise,unsupervice

# %% [markdown]
# # Numpy
# - NumPy, short for Numerical Python is the foundational open-source library for scientific computing, data science, and machine learning in Python. Created by Travis Oliphant in 2005, it adds powerful support for large, multidimensional arrays and matrices along with a massive collection of high-level mathematical functions to manipulate them.
