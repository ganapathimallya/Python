# %% [markdown]
# String declaration

# %%
s1='hello'
print(s1)
s2="I'm me"
print(s2)
s3="""hello "world" """
print(s3)
# Out:
# hello
# I'm me
# hello "world"

# %% [markdown]
# Escape Charecter

# %%
print("hello\nworld")
print("hello\tworld")
# Out:
# hello
# world
# hello	world

# %% [markdown]
# String indexing & slicing

# %%
str="hello world"

# %%
#indexing
print(str[6])
print(str[-1])
# Out:
# w
# d

# %%
print(str[4::-2])
#revese a string
print(str[::-1])
# Out:
# olh
# dlrow olleh

# %% [markdown]
# String Output Formating

# %%
name="Ganapathi Mallya"
age=20
place="Bangalore"
print(f"My name is {name}. I am {age} years old. I live in {place}.")
# Out:
# My name is Ganapathi Mallya. I am 20 years old. I live in Bangalore.

# %% [markdown]
# String function

# %%
s="The One Piece"

# %%
print(s+" Is Real")
print(s.endswith("Real"))
print(s.startswith("The"))
print(s.find("One"))
print(s.isalpha())
print(s.replace("Piece","Punch Man"))
print(s.split(" "))
print(s.upper())
# Out:
# The One Piece Is Real
# False
# True
# 4
# False
# The One Punch Man
# ['The', 'One', 'Piece']
# THE ONE PIECE
