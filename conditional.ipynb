# %%
age=int(input("enter ur age"))
if(age>=18):
    print("allowed")
else:
    print("not allowed")
# Out:
# allowed

# %% [markdown]
# if elif else

# %%
age=int(input("enter ur age"))
if(age<=3):
    print("child")
elif(age>=4 and age<=12):
    print("kid")
elif(age>=13 and age<=18):
    print("Teenager")
elif(age>=19 and age<=60):
    print("adult")
else:
    print("elder")
# Out:
# elder

# %% [markdown]
# shorthand

# %%
a=10
b=15
bigger=a if a>b else b
print(bigger)
# Out:
# 15

# %%
n=int(input("Enter a number"))
if n>0:
    print("profit")
elif n<0:
    print("loss")
else:
    print("no profit or loss")
# Out:
# loss

# %%
n=int(input("Enter a temparature"))
if n<20:
    print("Water is Cold")
elif n>=20 and n<=40:
    print("Water is normal")
else:
    print("water is hot")
# Out:
# water is hot

# %%
age=int(input("enter age"))
price=float(input("enter the price"))
if(age<12):
    print("discount = 50%")
    discount=price*0.5
    print("Final price",(price-discount))
elif(age>=12 and age<=60):
    print("No discount")
    print()
